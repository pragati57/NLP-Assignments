# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('/content/corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      Ladies and gentlemen, please welcome to the st...          Ali Wong
# anthony  Thank you. Thank you. Thank you, San Francisco...  Anthony Jeselnik
# bill     [cheers and applause] All right, thank you! Th...         Bill Burr
# bo       Bo What? Old MacDonald had a farm E I E I O An...        Bo Burnham
# dave     This is Dave. He tells dirty jokes for a livin...    Dave Chappelle
# hasan    [theme music: orchestral hip-hop] [crowd roars...      Hasan Minhaj
# jim      [Car horn honks] [Audience cheering] [Announce...     Jim Jefferies
# joe      [rock music playing] [audience cheering] [anno...         Joe Rogan
# john     All right, Petunia. Wish me luck out there. Yo...      John Mulaney
# louis    Intro\nFade the music out. Let’s roll. Hold th...        Louis C.K.
# mike     Wow. Hey, thank you. Thanks. Thank you, guys. ...    Mike Birbiglia
# ricky    Hello. Hello! How you doing? Great. Thank you....     Ricky Gervais

# %%
# Extract only Ali Wong's text
mike_text = data.transcript.loc['mike']
mike_text[:200]
# Out:
# 'Wow. Hey, thank you. Thanks. Thank you, guys. Hey, Seattle. Nice to see you. Look at this. Look at us. We’re here. This is crazy. It’s insane. So about five years ago, pretty much everyone who I know '

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
mike_dict = markov_chain(mike_text)
mike_dict
# Out:
# {'Wow.': ['Hey,'],
#  'Hey,': ['thank', 'Seattle.'],
#  'thank': ['you.', 'you.”', 'you.”'],
#  'you.': ['Thanks.', 'Look', 'Thank'],
#  'Thanks.': ['Thank'],
#  'Thank': ['you,', 'you', 'you.', 'you'],
#  'you,': ['guys.', 'but,', 'sir,', 'and', '“and'],
#  'guys.': ['Hey,'],
#  'Seattle.': ['Nice', 'So', 'I'],
#  'Nice': ['to'],
#  'to': ['see',
#   'get',
#   'my',
#   '62%',
#   '75%',
#   'be',
#   'stop',
#   'get',
#   'dinner.',
#   'do?”',
#   'give',
#   'be',
#   'tell',
#   'head',
#   'my',
#   'go',
#   'sleep',
#   'be',
#   'say',
#   'wear',
#   'dress',
#   'perpetuate',
#   'make',
#   'charge',
#   'a',
#   'strike',
#   'happen,',
#   'come',
#   'one',
#   'my',
#   'ask',
#   'ask',
#   'the',
#   'the',
#   'make',
#   'get',
#   'come',
#   'convince',
#   'fall',
#   'me',
#   'our',
#   'the',
#   'walk',
#   'her',
#   'her',
#   'end.',
#   'lean',
#   'kiss',
#   'me.',
#   'order.',
#   'try',
#   'get',
#   'a',
#   'talk',
#   'me',
#   'alphabetical',
#   'do',
#   'stop.',
#   'a',
#   'get',
#   'pee.',
#   'ask',
#   'go',
#   'the',
#   'the',
#   'Phil',
#   'move',
#   'interview',
#   'me,',
#   'the',
#   'throw',
#   'the',
#   'come',
#   'tell',
#   'stop',
#   'tell',
#   'stop',
#   'tell',
#   'stop',
#   'tell',
#   'stop',
#   'say',
#   'our',
#   'describe',
#   'lie',
#   'my',
#   'these',
#   'repeat.',
#   'hurt',
#   'young',
#   'Heaven,',
#   'fidget.',
#   'the',
#   'fidget.',
#   'heaven,',
#   'make',
#   'be',
#   'do',
#   'be',
#   'convince',
#   'talk',
#   'him,',
#   'Sandra,',
#   'my',
#   'play',
#   'be',
#   'kiss',
#   'go',
#   'a',
#   'show',
#   'dinner,',
#   'me,',
#   'show',
#   'do',
#   'tell',
#   'go',
#   'a',
#   'dinner',
#   'tell',
#   'ask',
#   'go',
#   'Bermuda.',
#   'show',
#   'Bermuda',
#   'security,',
#   'dwell',
#   'the',
#   'recruit',
#   'offer',
#   'guarantee',
#   'be',
#   'have',
#   'Bermuda,',
#   'get',
#   'talk',
#   'me,',
#   'her.',
#   'say',
#   'let',
#   '1,',
#   '1.',
#   'know',
#   'hang',
#   'know',
#   'be',
#   'write',
#   'write',
#   'do',
#   'overlook',
#   'me,',
#   'this',
#   'side.',
#   'a',
#   'tell',
#   'be',
#   'be',
#   'meet',
#   'Amanda’s',
#   'the',
#   'the',
#   'my',
#   'make',
#   'me,',
#   'me',
#   'meet',
#   'organize',
#   'say',
#   'dislike.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'be',
#   'help.',
#   'the',
#   'catch',
#   'Jenny’s',
#   'me',
#   'deliver',
#   'the',
#   'stand',
#   'die.',
#   'die,',
#   'give',
#   'see',
#   'get',
#   'the',
#   'the',
#   'hers,',
#   'the',
#   'come',
#   'be',
#   'get',
#   'be',
#   'be',
#   'be',
#   'more',
#   'classes',
#   'more',
#   'have',
#   'Jenny.',
#   'get',
#   'any',
#   'catch',
#   'Los',
#   'the',
#   'the',
#   'the',
#   'the',
#   'take',
#   'the',
#   'run.',
#   'run',
#   'do.',
#   'the',
#   'the',
#   'wait.”',
#   'the',
#   'the',
#   'the',
#   'Los',
#   'my',
#   'tell',
#   'exist.',
#   'a',
#   'the',
#   'the',
#   'wait',
#   'him,',
#   'jail',
#   'call',
#   'get',
#   'New',
#   'the',
#   'go,',
#   'get',
#   'his',
#   'reach',
#   'me,',
#   'any',
#   'pay',
#   'another?”',
#   'about',
#   'a',
#   'me',
#   'me',
#   'dinner',
#   'me,',
#   'and',
#   'the',
#   'say',
#   'city'],
#  'see': ['you.',
#   'two',
#   'there’s,',
#   'that',
#   'other',
#   'the',
#   'Khalid',
#   'how',
#   'now',
#   'what',
#   'that',
#   'how',
#   'you.”',
#   'each',
#   'how'],
#  'Look': ['at', 'at'],
#  'at': ['this.',
#   'us.',
#   'the',
#   'it.',
#   'point',
#   'Andy’s',
#   'a',
#   'me,',
#   'least',
#   'that',
#   'it',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Lisa,',
#   'any',
#   'Lisa,',
#   'any',
#   'Lisa,',
#   'any',
#   'Lisa.',
#   'me',
#   'that',
#   'the',
#   '8:00.',
#   '10:00.',
#   'some',
#   'the',
#   'the',
#   'fast',
#   '1/5',
#   'work,”',
#   'once,',
#   'the',
#   'the',
#   'our',
#   'one',
#   'dinner,',
#   '2:00',
#   'one',
#   'all.',
#   'the',
#   'the',
#   'all.',
#   'home,',
#   'his',
#   'a',
#   'this',
#   'their',
#   'me.',
#   'the',
#   'least',
#   'night,',
#   '6:20',
#   'me,',
#   'that',
#   'the',
#   'my',
#   'the',
#   'Andy’s',
#   'fault',
#   'a',
#   'the',
#   'the',
#   'fault.',
#   'this',
#   'this',
#   'a',
#   'me,'],
#  'this.': ['Look', 'I', '“I'],
#  'us.': ['We’re', 'And,', 'And'],
#  'We’re': ['here.', 'in', 'at', 'out', 'not'],
#  'here.': ['This', 'Yeah.'],
#  'This': ['is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'was',
#   'guy',
#   'is',
#   'is',
#   'part',
#   'is',
#   'isn’t'],
#  'is': ['crazy.',
#   'that',
#   'my',
#   'what',
#   'the',
#   'really',
#   'a',
#   'to',
#   'the',
#   'the',
#   'my',
#   'God,',
#   'large',
#   'fast,',
#   'ridiculous.',
#   'only',
#   'wearing',
#   'wrong',
#   'this?',
#   'we',
#   'the',
#   'a',
#   'fine.',
#   'just',
#   'in',
#   'she',
#   'great.',
#   'bad,',
#   'there.',
#   'a',
#   'very',
#   'part',
#   'part',
#   'a',
#   'a',
#   'a',
#   'very',
#   'not',
#   'in',
#   'a',
#   'an',
#   'a',
#   'very',
#   'a',
#   'you',
#   'if',
#   'happening',
#   'no…',
#   'more',
#   'taking',
#   'I',
#   'she',
#   'this,',
#   'also',
#   'a',
#   'I',
#   'that…',
#   'what',
#   'true,',
#   'it.',
#   'about.',
#   'you',
#   'the',
#   'Scott.',
#   'indescribable',
#   'angry',
#   'a',
#   'very',
#   'that',
#   'better',
#   'it…',
#   'an',
#   'the',
#   'not',
#   'religious,',
#   'insane!',
#   'where',
#   'this',
#   'what',
#   'closed,',
#   'me',
#   'not',
#   'the',
#   'messing',
#   'a',
#   'even',
#   'really',
#   'he',
#   'Chinatown!',
#   'when',
#   'a',
#   'way',
#   'my'],
#  'crazy.': ['It’s'],
#  'It’s': ['insane.',
#   'going',
#   'like',
#   'basically',
#   'not',
#   'like',
#   'like',
#   'like',
#   'like',
#   'dawning',
#   'such',
#   'like',
#   'like',
#   'not',
#   '5:00',
#   'just'],
#  'insane.': ['So'],
#  'So': ['about',
#   'February',
#   'I’m',
#   'I’ve',
#   'spent',
#   'here’s',
#   'I’m',
#   'he',
#   'she’s',
#   'I’m',
#   'instead',
#   'I',
#   'we’re',
#   'I',
#   'we',
#   'I',
#   'I',
#   'I',
#   'I’m',
#   'I',
#   'now'],
#  'about': ['five',
#   'something,',
#   'to',
#   'his',
#   'this',
#   'this.',
#   'to',
#   'a',
#   'to',
#   'that.',
#   'my',
#   'a',
#   'anyone.',
#   'homework,',
#   'your',
#   'the',
#   'the',
#   'the',
#   'scrambler',
#   'slow',
#   'making',
#   'the',
#   'right.',
#   'nine',
#   'that,',
#   'bombs.',
#   'her',
#   'how',
#   'this',
#   'it.”',
#   'essentially',
#   'it',
#   'essentially',
#   'everything,',
#   'things',
#   'little',
#   'big',
#   'her',
#   'John?',
#   'six',
#   'to',
#   'Texas.',
#   'this',
#   'money,',
#   'stopping',
#   'money.”',
#   '4:00'],
#  'five': ['years', 'days'],
#  'years': ['ago,', 'trying', 'old,', 'old', 'later,', 'old,'],
#  'ago,': ['pretty'],
#  'pretty': ['much',
#   'good',
#   'good.',
#   'well,',
#   'sure',
#   'well.',
#   'self-destructive'],
#  'much': ['everyone', 'as', 'better', 'convincing', 'money', 'more', 'bigger'],
#  'everyone': ['who', 'knows'],
#  'who': ['I',
#   'just',
#   'are',
#   'sat',
#   'I',
#   'will',
#   'are',
#   'you',
#   'writes',
#   'you',
#   'was',
#   'could',
#   'has',
#   'would',
#   'have',
#   'would'],
#  'I': ['know',
#   'don’t',
#   'have',
#   'think',
#   'am',
#   'remember',
#   'was',
#   'think',
#   'said,',
#   'say',
#   'think',
#   'think',
#   'mean,',
#   'say',
#   'said,',
#   'say,',
#   'think',
#   'didn’t',
#   'had',
#   'mean,',
#   'got',
#   'knew',
#   'was',
#   'go,',
#   'go,',
#   'got',
#   'get',
#   'don’t',
#   'think',
#   'hear',
#   'hear',
#   'know.',
#   'met',
#   'were',
#   'was',
#   'was',
#   'was,',
#   'said,',
#   'was',
#   'said,',
#   'think',
#   'was',
#   'met',
#   'knew',
#   'wanted',
#   'mean…',
#   'mean',
#   'was',
#   'was',
#   'just',
#   'met',
#   'just',
#   'didn’t…',
#   'didn’t',
#   'don’t',
#   'actually',
#   'was',
#   'just',
#   'decided',
#   'didn’t…',
#   'didn’t',
#   'mean,',
#   'like',
#   'might',
#   'don’t',
#   'leave',
#   'glance',
#   'mean?',
#   'don’t',
#   'stare',
#   'get',
#   'feel',
#   'go',
#   'have',
#   'just…',
#   'would',
#   'always',
#   'root',
#   'don’t',
#   'got',
#   'totally',
#   'really',
#   'thought',
#   'don’t',
#   'didn’t',
#   'convinced',
#   'don’t',
#   'left',
#   'was',
#   'was',
#   'was',
#   'do',
#   'said…',
#   'had',
#   'caught',
#   'were',
#   'could',
#   'told',
#   'offer',
#   'didn’t',
#   'build',
#   'thought',
#   'mean,',
#   'have',
#   'remember',
#   'remember…',
#   'remember',
#   'was',
#   'was',
#   'was',
#   'was',
#   'see',
#   'feel',
#   'make',
#   'was',
#   'mean,',
#   'would',
#   'don’t',
#   'feared…',
#   'feared',
#   'would',
#   'was',
#   'didn’t',
#   'had',
#   'don’t…',
#   'was',
#   'had',
#   'said',
#   'was',
#   'got',
#   'remember',
#   'was',
#   'ended',
#   'built',
#   'couldn’t',
#   'thought,',
#   'think',
#   'don’t',
#   'imagine',
#   'understand',
#   'have',
#   'feel',
#   'don’t',
#   'think',
#   'knew',
#   'was',
#   'even',
#   'was',
#   'am',
#   'was',
#   'need',
#   'needed',
#   'think',
#   'said,',
#   'started',
#   'did',
#   'was',
#   'was',
#   'did',
#   'attended',
#   'was,',
#   'had',
#   'had',
#   'always',
#   'think',
#   'know',
#   'know',
#   'would',
#   'feared',
#   'fidgeted',
#   'might',
#   'didn’t',
#   'could',
#   'had',
#   'could',
#   'was',
#   'don’t',
#   'make',
#   'can',
#   'wanted',
#   'couldn’t',
#   'walked',
#   'had',
#   'started',
#   'should',
#   'got',
#   'remember',
#   'mean?',
#   'remember',
#   'remember',
#   'was',
#   'read',
#   'just',
#   'couldn’t',
#   'was…',
#   'was',
#   'said',
#   'was',
#   'was',
#   'was',
#   'was',
#   'couldn’t',
#   'couldn’t',
#   'had',
#   'had',
#   'lean',
#   'typed',
#   'took',
#   'couldn’t',
#   'could',
#   'said,',
#   'love',
#   'go,',
#   'pulled',
#   'didn’t',
#   'said,',
#   'was',
#   'got',
#   'do',
#   'went',
#   'ended',
#   'said,',
#   'did',
#   'ended',
#   'could',
#   'was',
#   'won’t',
#   'said,',
#   'said,',
#   'said,',
#   'built',
#   'wanted',
#   'could',
#   'didn’t',
#   'meet',
#   'fancy',
#   'have',
#   'have',
#   'never',
#   'said,',
#   'go,',
#   'don’t',
#   'just',
#   'find',
#   'mean,',
#   'were',
#   'would',
#   'would',
#   'mean,',
#   'was',
#   'had',
#   'don’t',
#   'don’t',
#   'said,',
#   'don’t',
#   'said,',
#   'go,',
#   'said,',
#   'said,',
#   'said,',
#   'don’t',
#   'was',
#   'was',
#   'don’t',
#   'was',
#   'don’t',
#   'feel.”',
#   'feel.”',
#   'feel.”',
#   'was',
#   'said,',
#   'think',
#   'would',
#   'go,',
#   'know',
#   'know',
#   'just',
#   'just',
#   'mean,',
#   'mean,',
#   'was',
#   'was',
#   'said,',
#   'go,',
#   'just',
#   'said,',
#   'feel.”',
#   'said,',
#   'remember',
#   'fell',
#   'was',
#   'found',
#   'was',
#   'thought',
#   'was',
#   'was',
#   'just…',
#   'thought',
#   'wanted',
#   'was',
#   'want',
#   'was',
#   'don’t…',
#   'don’t',
#   'was',
#   'transferred',
#   'don’t',
#   'think',
#   'know.',
#   'think',
#   'can',
#   'perceived',
#   'was',
#   'tried',
#   'went',
#   'thought,',
#   'need.',
#   'drive',
#   'walk',
#   'mean,',
#   'could',
#   'remember',
#   'met',
#   'said,',
#   'was',
#   'felt',
#   'drove',
#   'remember',
#   'was',
#   'was',
#   'dislike',
#   'just',
#   'developed',
#   'was',
#   'love',
#   'didn’t',
#   'didn’t',
#   'feel',
#   'were',
#   'leave',
#   'just…',
#   'just',
#   'was',
#   'was',
#   'always',
#   'was',
#   'can',
#   'don’t',
#   'wake',
#   'roll',
#   'run',
#   'land',
#   'get',
#   'walk',
#   'pulled',
#   'was',
#   'aren’t',
#   'said,',
#   'feel',
#   'said,',
#   'said,',
#   'glance',
#   'do',
#   'say,',
#   'said,',
#   'was',
#   'mean,',
#   'didn’t',
#   'was',
#   'said,',
#   'told',
#   'said,',
#   'don’t',
#   'think',
#   'work',
#   'just',
#   'said,',
#   'missed',
#   'kept',
#   'wanted',
#   'think,',
#   'caved',
#   'called',
#   'said,',
#   'really',
#   'want',
#   'took',
#   'said,',
#   'said,',
#   'really',
#   'don’t',
#   'feel.”',
#   'said,',
#   'said,',
#   'don’t',
#   'said,',
#   'said,',
#   'don’t',
#   'think',
#   'don’t',
#   'just',
#   'believe',
#   'feel!”',
#   'explain',
#   'would',
#   'said,',
#   'feel.”',
#   'had',
#   'was',
#   'walk',
#   'get',
#   'get',
#   'print',
#   'bring',
#   'guess',
#   'had',
#   'was',
#   'wasn’t',
#   'had',
#   'photoshopped',
#   'was',
#   'start',
#   'hear',
#   'guess',
#   'was',
#   'started',
#   'have',
#   'was',
#   'get',
#   'was',
#   'want',
#   'was',
#   'miss',
#   'can',
#   'run',
#   'sit',
#   'fall',
#   'wake',
#   'jump',
#   'am',
#   'think',
#   'needed',
#   'was',
#   'know',
#   'ran',
#   'started',
#   'was',
#   'missed',
#   'got',
#   'feel',
#   'get',
#   'get',
#   'said,',
#   'go,',
#   'go,',
#   'got',
#   'drive',
#   'think',
#   'hear',
#   'hear',
#   'start',
#   'guess',
#   'should',
#   'might',
#   'said',
#   'don’t',
#   'said,',
#   'heard',
#   'heard',
#   'can’t',
#   'said,',
#   'was',
#   'was',
#   'signed',
#   'can’t',
#   'flash',
#   'have',
#   'say,',
#   'said,',
#   'pick',
#   'dial',
#   'fly',
#   'get',
#   'just',
#   'owed…',
#   'was',
#   'explained',
#   'requested',
#   'don’t',
#   'would',
#   'understand',
#   'hurt',
#   'was',
#   'came',
#   'had',
#   'know',
#   'get',
#   'explain',
#   'know,',
#   'mean,',
#   'said.',
#   'go,',
#   'go,',
#   'would',
#   'started',
#   'said,',
#   'said,',
#   'start',
#   'get',
#   'know',
#   'know',
#   'know',
#   'was',
#   'have',
#   'said,',
#   'said,',
#   'think',
#   'give',
#   'pay',
#   'went',
#   'still',
#   'still',
#   'believe'],
#  'know': ['started',
#   'that',
#   'I’m',
#   'if',
#   'what',
#   'how',
#   'how',
#   'if',
#   'are',
#   'if',
#   'that',
#   'if',
#   'it’s',
#   'I’ve',
#   'anything',
#   'what',
#   'I',
#   'that',
#   'that',
#   'what',
#   'what',
#   'when',
#   'what',
#   'Amanda?”',
#   'if',
#   'these',
#   'is',
#   'how',
#   'how',
#   'if',
#   'if',
#   'what',
#   'where',
#   '’cause',
#   'this',
#   'where',
#   'what'],
#  'started': ['to',
#   'making',
#   'throwing',
#   'fast',
#   'to',
#   'having',
#   'yet.',
#   'running.',
#   'pounding',
#   'to',
#   'printing'],
#  'get': ['married,',
#   'married,',
#   'engaged.',
#   'in',
#   'away',
#   'married,',
#   'angry.',
#   'it.”',
#   'to',
#   'Jenny',
#   'back',
#   'to',
#   'into',
#   'Lisa',
#   'stuck',
#   'it,',
#   'that',
#   'that',
#   'that',
#   'these',
#   'to',
#   'a',
#   'married',
#   'married',
#   'a',
#   'a',
#   'one.”',
#   'one',
#   'one,',
#   'a',
#   'to',
#   'a',
#   'back',
#   'a',
#   'married',
#   'engaged,',
#   'married,',
#   'to',
#   'to',
#   'to',
#   'to',
#   'on',
#   'me',
#   'to',
#   'back',
#   'married.”',
#   'a',
#   'officer',
#   'him',
#   'a',
#   'away',
#   'a'],
#  'married,': ['and', 'we', 'and…', 'I'],
#  'and': ['that',
#   'the',
#   'she',
#   'he’s',
#   'it',
#   'I’m',
#   'I’m',
#   'I',
#   'drive',
#   'I',
#   'I',
#   'she',
#   'then',
#   'I’m…',
#   'this',
#   'the',
#   'my',
#   'my',
#   'I’m',
#   'twirls.',
#   'it’s',
#   'Andy',
#   'so',
#   'Jenny',
#   'get',
#   'there’s',
#   'it',
#   'that’s…',
#   'it',
#   'she',
#   'then,',
#   'having',
#   'we…',
#   'she',
#   'I',
#   'I',
#   'I',
#   'she',
#   'I',
#   'she',
#   'the',
#   'we',
#   'I',
#   'I',
#   'she',
#   'she',
#   'a',
#   'it',
#   'peanuts',
#   'ice',
#   'cotton',
#   'then',
#   'that',
#   'it',
#   'I’m',
#   'I’m',
#   'that',
#   'it',
#   'hormones',
#   'drakkar',
#   'led',
#   'making',
#   'tell',
#   'I’m',
#   'then',
#   'the',
#   'said',
#   'this',
#   'those',
#   'the',
#   'so',
#   'she',
#   'she',
#   'she',
#   'I',
#   'from',
#   'she',
#   'I',
#   'that',
#   'you',
#   'I',
#   'after',
#   'I',
#   'she',
#   'I',
#   'she’s',
#   'my',
#   'I',
#   'Jenny’s',
#   'I’m',
#   'my',
#   'women,',
#   'no',
#   'they',
#   'we’re',
#   'the',
#   'she',
#   'Jenny',
#   'they',
#   'they',
#   'they',
#   'spend',
#   'I',
#   'we',
#   'she',
#   'then',
#   'play.”',
#   'played',
#   'I',
#   'then,',
#   'then',
#   'it',
#   'you’re',
#   'I’m',
#   'she',
#   'funny.',
#   'she',
#   'I',
#   'he',
#   'no',
#   'Mike’s',
#   'I',
#   'there’s',
#   'there’s',
#   'it’s',
#   'this',
#   'his',
#   'things',
#   'they’re',
#   'she',
#   'me',
#   'I',
#   'I',
#   'it',
#   'I',
#   'the',
#   'then',
#   'they’re',
#   'after',
#   'I’m',
#   'I’m',
#   'I',
#   'I',
#   'there’s',
#   'there’s',
#   'center.',
#   'doing',
#   'I',
#   'realize',
#   'I',
#   'the',
#   'I',
#   'I',
#   'I',
#   'we',
#   'a',
#   'then',
#   'she',
#   'she',
#   'so',
#   'Andy’s',
#   'we',
#   'suggesting',
#   'we',
#   'I’m',
#   'I’m',
#   'I',
#   'I',
#   'I',
#   'she',
#   'she',
#   'been',
#   'been',
#   'I',
#   'I',
#   'it',
#   'I’m',
#   'then',
#   'I',
#   'I’m',
#   'I’m',
#   'I',
#   'the',
#   'I',
#   'a',
#   'the',
#   'the',
#   'I',
#   'I’d',
#   'I’m',
#   'I',
#   'I’m',
#   'I',
#   'drive',
#   'that’s',
#   'realizing',
#   'he',
#   'then',
#   'drive',
#   'veered',
#   'run',
#   'hit.”',
#   'he',
#   'that',
#   'it’s',
#   'Andy',
#   'it',
#   'I',
#   'I',
#   'tell',
#   'I',
#   'he',
#   'a',
#   'that',
#   'I’m',
#   'passenger',
#   'vehicle',
#   'I',
#   'I’m',
#   'he',
#   'pay',
#   'pay',
#   'it’s',
#   'California',
#   'private',
#   'he',
#   'he',
#   'this',
#   'I’m',
#   'she’s',
#   'the',
#   'going',
#   'the',
#   'the',
#   'she',
#   'I',
#   'I',
#   'I',
#   'I',
#   'got',
#   'I',
#   'I’ve',
#   'joining'],
#  'that': ['was',
#   'would',
#   'I',
#   'I’m',
#   'I’m',
#   'men',
#   'would',
#   'I',
#   'crazy,',
#   'in,',
#   'was',
#   'I',
#   'point.',
#   'kind',
#   'if',
#   'I',
#   'behavior',
#   'night',
#   'might',
#   'was',
#   'wasn’t',
#   'is',
#   'way',
#   'right?',
#   'was',
#   'were',
#   'soon',
#   'made',
#   'more.”',
#   'when',
#   'you',
#   'pod',
#   'bar',
#   'they',
#   'they',
#   'I',
#   'the',
#   'point.',
#   'evening.',
#   '’cause',
#   'one.”',
#   'conversation',
#   'one.”',
#   'one.”',
#   'there',
#   'was',
#   'space?',
#   'area.',
#   'analogy,',
#   'crescendo…',
#   'point,',
#   'I’d',
#   'one',
#   'one',
#   'before.”',
#   'sounds',
#   'point',
#   'she',
#   'way',
#   'as',
#   'didn’t',
#   'something',
#   'happens,',
#   'I',
#   'the',
#   'hot',
#   'based',
#   'argument.”',
#   'argument,”',
#   'I’d',
#   'what',
#   'in',
#   'first',
#   'she',
#   'when',
#   'she',
#   'she',
#   'in',
#   'were',
#   'that',
#   'wasn’t',
#   'were',
#   'wouldn’t',
#   'she',
#   'she',
#   'I',
#   'Amanda',
#   'I’m',
#   'when',
#   'happen.”',
#   'we',
#   'I’m',
#   'week',
#   'that',
#   'was',
#   'off',
#   'to',
#   'had',
#   'kind',
#   'gives',
#   'from?”',
#   'line',
#   'makes',
#   'as',
#   'we',
#   'to',
#   'to',
#   'we',
#   'we',
#   'goes',
#   'night.',
#   'part',
#   'ain’t',
#   'aggressive',
#   'point.',
#   'feature',
#   'psychological',
#   'I',
#   'have',
#   'night,',
#   'moment,',
#   'would',
#   'we',
#   'you’ve',
#   'we',
#   'the',
#   'I',
#   'I',
#   'he',
#   'finds',
#   'is,',
#   'we',
#   'week.',
#   'in',
#   'you’re',
#   'we'],
#  'was': ['strange',
#   'like,',
#   'about',
#   'a',
#   'right.',
#   'a',
#   'very',
#   'actually',
#   'like,',
#   'like,',
#   'like,',
#   'the',
#   'capable',
#   'so',
#   'gonna',
#   'a',
#   'naked.',
#   'the',
#   'like,',
#   'like,',
#   'like,',
#   'fine.',
#   'on',
#   'on',
#   'not',
#   'drinking,',
#   'really',
#   'polite…',
#   'in',
#   'yesterday',
#   'shocked.',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'fine',
#   'like,',
#   'a',
#   'like,',
#   'a',
#   'one',
#   'way',
#   'in',
#   'like,',
#   'laughing',
#   'like,',
#   'the',
#   'originally',
#   'called',
#   'wildly',
#   'co-opted',
#   'going',
#   'like,',
#   'gone.',
#   'very',
#   'just',
#   'like,',
#   'I',
#   'not',
#   'staring',
#   'a',
#   'spectacular.',
#   'a',
#   'just',
#   'actually',
#   'the',
#   'like,',
#   'like',
#   'tell',
#   'like,',
#   'like,',
#   'standing',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'so',
#   'it',
#   'true.',
#   'like,',
#   'your',
#   'great.',
#   'wrong.',
#   'like,',
#   'the',
#   'a',
#   'your',
#   'opening',
#   'opening',
#   'like,',
#   'like,',
#   'a',
#   'like,',
#   'just',
#   'just',
#   'having',
#   'just',
#   'in',
#   'that',
#   'Amanda,',
#   'really',
#   'that',
#   'like',
#   'a',
#   'like,',
#   'totally',
#   'this',
#   'framed.”',
#   'just',
#   'like',
#   'like',
#   'like',
#   'like,',
#   'like,',
#   'that',
#   'that',
#   'a',
#   'kind',
#   'at.',
#   'this',
#   'a',
#   'lying',
#   'that',
#   'my',
#   'so',
#   'even',
#   'a',
#   'some',
#   'as',
#   'so',
#   'a',
#   'intense,',
#   'a',
#   'away',
#   'coming',
#   'awful',
#   'performing',
#   'part',
#   'the',
#   'performing',
#   'approached',
#   'like,',
#   'just',
#   'in',
#   'like,',
#   'this',
#   'drunk.”',
#   'like,',
#   'he',
#   'the',
#   'like',
#   'wildly',
#   'heading',
#   '5:00',
#   'doing',
#   'as',
#   'like,',
#   'not',
#   'like,',
#   'late',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'a',
#   'really',
#   'like,',
#   'the',
#   'like,',
#   'clearly',
#   'definitely',
#   'on',
#   'going',
#   'driving.',
#   'going,',
#   'clearly',
#   'an',
#   'gonna',
#   'like,',
#   'Jenny.'],
#  'strange': ['for'],
#  'for': ['me',
#   'you,',
#   'other',
#   'anyone.”',
#   'more',
#   'example,',
#   'her',
#   'a',
#   'you.”',
#   'fried',
#   'a',
#   'strong,',
#   'this',
#   'it.',
#   'starters.”',
#   'us.',
#   'Jenny,',
#   'Andy',
#   'a',
#   'me.',
#   'our',
#   'a',
#   'constipated',
#   'sure.',
#   'burgers.',
#   'my',
#   'example,',
#   'six',
#   'me',
#   'dealing',
#   'anything.',
#   'the',
#   'the',
#   'a',
#   'the',
#   'obvious',
#   'about',
#   'coffee.',
#   'her',
#   'a',
#   'the',
#   'a',
#   'building,',
#   'a',
#   'a',
#   'the',
#   'cops.',
#   'the',
#   'his',
#   'the',
#   'people',
#   'vigilantes',
#   'a',
#   'a',
#   'the',
#   'this',
#   'coming'],
#  'me': ['because',
#   'and',
#   'tell',
#   'over',
#   'of',
#   'and',
#   'as',
#   'she',
#   'in',
#   'on',
#   'because',
#   'one',
#   'that',
#   'back.',
#   'back.”',
#   'in',
#   'her',
#   'at',
#   'if',
#   'on',
#   '“and',
#   'about',
#   'get',
#   'get',
#   'win.',
#   'was',
#   'for',
#   'not',
#   'at',
#   'to',
#   'that',
#   'here.”',
#   'again.”',
#   'to',
#   'and',
#   'in',
#   'to',
#   'and',
#   'and',
#   'and',
#   'on.',
#   'and',
#   'to',
#   'at',
#   'also…',
#   'at',
#   'to',
#   'entirely.',
#   'like,',
#   'at'],
#  'because': ['I',
#   'I',
#   'you’re',
#   'I',
#   'up',
#   'they’re',
#   'all',
#   'you',
#   'it',
#   'I',
#   'it',
#   'I’m'],
#  'don’t': ['really',
#   'believe',
#   'know',
#   'have',
#   'give',
#   'really',
#   'stare',
#   'even',
#   'know,',
#   'know',
#   'like',
#   'know,',
#   'understand',
#   'know',
#   'know',
#   'even',
#   'think',
#   'talk',
#   'look',
#   'look',
#   'pick',
#   'want',
#   'you',
#   'like',
#   'see',
#   'think',
#   'think',
#   'really',
#   'think',
#   'make',
#   'think',
#   'make',
#   'have',
#   'have',
#   'have',
#   'understand',
#   'want',
#   'mean',
#   'even',
#   'see',
#   'think',
#   'know',
#   'get',
#   'think',
#   'think',
#   'think',
#   'see',
#   'think',
#   'believe',
#   'buy',
#   'know.”',
#   'believe',
#   'want',
#   'even',
#   'want',
#   'eat',
#   'understand',
#   'believe',
#   'believe',
#   'want',
#   'want',
#   'really',
#   'know',
#   'know',
#   'know',
#   'know',
#   'you',
#   'you'],
#  'really': ['believe',
#   'simple.',
#   'my',
#   'soft,',
#   'was.',
#   'long,',
#   'look',
#   'wanted',
#   'quiet,',
#   'putting',
#   'talk',
#   'tough,',
#   'hurts',
#   'mess',
#   'smart',
#   'like',
#   'exciting',
#   'strong',
#   'mean',
#   'sorry.”',
#   'miss',
#   'don’t',
#   'believe',
#   'shaken',
#   'sorry,',
#   'everyone’s'],
#  'believe': ['in',
#   'in',
#   'in',
#   'it.',
#   'in',
#   'in?”',
#   'in',
#   'in',
#   'in',
#   '“in',
#   'in',
#   'in',
#   'in',
#   'in'],
#  'in': ['the',
#   'marriage',
#   'it',
#   'divorce.',
#   'divorce.',
#   'divorce.',
#   'all',
#   'the',
#   'Europe.',
#   'Los',
#   'the',
#   'an',
#   'this',
#   'the',
#   'my',
#   '1',
#   'St.',
#   'this',
#   'the',
#   'my',
#   'my',
#   'my',
#   'the',
#   'Seattle',
#   'the',
#   'a',
#   'a',
#   'St.',
#   'the',
#   'this',
#   'the',
#   'to',
#   'my',
#   'Massachusetts,',
#   'seventh',
#   'my',
#   'the',
#   'front',
#   'class',
#   'old',
#   'third',
#   'all',
#   'a',
#   'Seattle.',
#   'love',
#   'a',
#   'a',
#   'charge',
#   'a',
#   'which',
#   'the',
#   'between',
#   'that',
#   'stairway',
#   'strong,',
#   'the',
#   'to',
#   'New',
#   'New',
#   'my',
#   'another',
#   'the',
#   'you.”',
#   'that?”',
#   'love.',
#   'New',
#   'charge',
#   'a',
#   'the',
#   'front',
#   'my',
#   'the',
#   'an',
#   'me.”',
#   'the',
#   'love,',
#   'high',
#   'love,',
#   'student',
#   'love,',
#   'an',
#   'my',
#   'the',
#   'retrospect,',
#   'the',
#   'the',
#   'their',
#   'college,',
#   'him.',
#   'the',
#   'the',
#   'corporate…”\nWell,',
#   'general!”',
#   'perfect',
#   'Texas,',
#   'Texas.',
#   'some',
#   'charge',
#   'the',
#   'New',
#   'the',
#   'the',
#   'fact,',
#   'a',
#   'front',
#   'the',
#   'your',
#   'electrocutions.',
#   'Texas.\nJenny',
#   'the',
#   'a',
#   'the',
#   'some',
#   'together.',
#   'marriage,',
#   'anything,',
#   'marriage?”',
#   'the',
#   'a',
#   'love,',
#   'my',
#   'the',
#   'a',
#   '“just',
#   'a',
#   'the',
#   'my',
#   'the',
#   'this',
#   'another',
#   'circles',
#   'my',
#   'real',
#   'a',
#   'this',
#   'the',
#   'a',
#   'Texas.',
#   'the',
#   'front',
#   'that',
#   'anything,',
#   'my',
#   'my',
#   'my',
#   'the',
#   'my',
#   'the',
#   'the',
#   'her,'],
#  'the': ['idea',
#   'person',
#   'reason',
#   'way.',
#   'very',
#   'reaction.',
#   'hopeful',
#   'best',
#   'world.',
#   'sense',
#   'night,',
#   'phone,',
#   'kind',
#   'crazy',
#   'morning.”',
#   'culinary',
#   'other',
#   'kind',
#   'moment',
#   'most',
#   'most',
#   'idea',
#   'moment',
#   'shirt',
#   'real',
#   'backup',
#   'myth',
#   'mirror',
#   'mirror.',
#   'mirror,',
#   'house',
#   'ref',
#   'competing',
#   'field.',
#   'guy',
#   'class',
#   'more',
#   'instructor',
#   'Olympics.',
#   'end',
#   'same',
#   'nerve',
#   'best',
#   'car',
#   'pub,',
#   'hotel.”',
#   'pub,',
#   'bouncer',
#   'pub,',
#   'time',
#   'idea.',
#   'night',
#   'red',
#   'space',
#   'night',
#   'end',
#   'night,',
#   'back',
#   'hotel,',
#   'courage',
#   'most',
#   'girls',
#   'list.',
#   'street.”',
#   'class',
#   'make-out',
#   'non-make-out',
#   'non-make-out',
#   'day.',
#   'lone',
#   'non-make-out',
#   'make-out',
#   'show',
#   'trade',
#   'phone',
#   'phone',
#   'phone,',
#   'closest',
#   'next',
#   'courage',
#   'carnival',
#   'carnival,',
#   'top',
#   'Ferris',
#   'scrambler.',
#   'most',
#   'selling',
#   'sugar',
#   'insulation?”',
#   'product',
#   'information',
#   'scrambler',
#   'person',
#   '“shits',
#   'carnival',
#   'name',
#   '‘I',
#   'essence',
#   'machine.',
#   'added',
#   'original',
#   'machine,',
#   'name',
#   'scrambler?',
#   'scrambler,',
#   'bar',
#   'only',
#   'pavement,',
#   'scrambler',
#   'moment',
#   'bar',
#   '16-year-old',
#   'second',
#   'scrambler',
#   'ride,',
#   'scrambler',
#   'window',
#   'scrambler',
#   'ride.',
#   'ride.',
#   'ride.',
#   'ride!”',
#   'ride!',
#   'pavement',
#   'St.',
#   'girls',
#   'state',
#   'cattle.',
#   'cattle',
#   'lone',
#   'non-make-out',
#   'time.',
#   'dance,',
#   'last',
#   'dance.',
#   'worst',
#   'negative',
#   'strobe',
#   'speed.',
#   'only',
#   'middle',
#   'head',
#   'two',
#   'most',
#   'whole',
#   'giant',
#   'shore…',
#   'squid',
#   'song',
#   'tilt.',
#   'slightest',
#   'fork.',
#   'non-make-out',
#   'dance',
#   'week',
#   'whole',
#   'worst',
#   'worst',
#   'other',
#   'show,',
#   'conversation.',
#   'romantic',
#   'usual',
#   'contradiction',
#   'courage',
#   'off',
#   'airport,',
#   'plane',
#   'differences',
#   'airport',
#   'plane.',
#   '72',
#   'women',
#   '72',
#   'odds,',
#   'first',
#   '72',
#   'same',
#   'flight…',
#   'flight,',
#   'flight',
#   'same',
#   'bus,',
#   'rest',
#   'kinds',
#   'morning,',
#   'law.”',
#   'definition',
#   'trip,',
#   'girl',
#   'guy',
#   'score.”',
#   'morning',
#   'first',
#   'newspaper.',
#   'newspaper?”',
#   'school',
#   'all',
#   'jedi',
#   'future',
#   'time,',
#   'process',
#   'affirmation',
#   'main',
#   'front',
#   'house,',
#   'other',
#   'kitchen',
#   'bathroom,',
#   'decision',
#   'boys',
#   'day',
#   'first',
#   'week.',
#   'point',
#   'last',
#   'art',
#   'weekends,',
#   'female',
#   'penis',
#   'gummy',
#   'penis.',
#   'candification',
#   'penis,',
#   'gummy',
#   'side.',
#   'experts,',
#   'comedy',
#   'late',
#   'my',
#   'airport',
#   'front',
#   'pool,',
#   'last',
#   'edge.”',
#   'mirror',
#   'argument',
#   'way',
#   'street',
#   'truth.”',
#   'balls.',
#   'time.',
#   'day.',
#   'form',
#   'smallest',
#   'D.M.V.',
#   'government',
#   'triple',
#   'wedding',
#   'flamboyant',
#   'middle',
#   'person',
#   'rest',
#   'government',
#   'mail',
#   'religion?',
#   'people',
#   'altar',
#   'religion',
#   'church',
#   'priest',
#   'morning,',
#   'morning',
#   'earth',
#   'road',
#   'code',
#   'airport.',
#   'kiosk,',
#   'security',
#   'gate,',
#   'way',
#   'decision',
#   'kiosk',
#   'tram,',
#   'roller',
#   'hotel,',
#   'tram,',
#   'next',
#   'tram’s',
#   'cancer',
#   'next',
#   'gate,',
#   'gate,',
#   'sound',
#   'door',
#   'door',
#   'sad',
#   'door.',
#   'Cinnabon',
#   'Cinnabon',
#   'size',
#   'people',
#   'plane.',
#   'Cinnabon',
#   'airline',
#   'white',
#   'cinnamon',
#   'giant',
#   'window',
#   'next',
#   'phone',
#   'morning!”',
#   'culinary',
#   'other',
#   'police',
#   'ground,',
#   'concept',
#   'ground',
#   'end',
#   'other',
#   'light.',
#   'light',
#   'officer',
#   'hospital',
#   'other',
#   'doctor,',
#   'other',
#   'doctor',
#   'technique',
#   'hardy',
#   'morning,',
#   'phone,',
#   'accident',
#   'accident',
#   'repairs',
#   'other',
#   'woman,',
#   'accident',
#   'accident',
#   'actual',
#   'homework.',
#   'scene',
#   'accident',
#   'beach.',
#   'one',
#   'home/beach/pub.\nSo',
#   'box',
#   'phone,',
#   'phone,',
#   'right',
#   'guy’s',
#   'right',
#   'guy’s',
#   'phone.',
#   'law.',
#   'scene',
#   'accident',
#   'phone',
#   'case.',
#   'accident?”',
#   'accident?”',
#   'case,',
#   'web.',
#   'entire',
#   'case',
#   'intersection,',
#   'angles',
#   'cars',
#   'lanes',
#   'laws',
#   'other',
#   'phone',
#   'point',
#   'napkin.',
#   'morning?”',
#   'case,',
#   'idea',
#   'idea'],
#  'idea': ['of', 'of', '’cause,', 'of', 'of'],
#  'of': ['marriage.',
#   'tension',
#   'tension',
#   'course,',
#   'all,',
#   'marriages',
#   'all,',
#   'being',
#   'that?',
#   'what',
#   'a',
#   'friend',
#   'whether',
#   'Andy’s',
#   'describing',
#   'wrestling',
#   'about',
#   'times',
#   'manic',
#   'voice',
#   'get',
#   'in',
#   'swore',
#   'marriage',
#   'confidence.',
#   'myself',
#   'that.',
#   'skip',
#   'the',
#   'the',
#   'trouble.',
#   'that,',
#   'these',
#   'waved',
#   'the',
#   'their',
#   'a',
#   'rejection',
#   'a',
#   'failed',
#   'a',
#   'divided',
#   'course.',
#   'the',
#   'business,',
#   'business,',
#   'the',
#   'girls,',
#   'me',
#   'my',
#   'the',
#   'us,',
#   'a',
#   'those',
#   'the',
#   'these',
#   'a',
#   'an',
#   'pants-erator,”',
#   'America.',
#   'a',
#   'how',
#   'the',
#   'a',
#   'this',
#   'equipment?”',
#   'safety',
#   'held',
#   'scrambler',
#   'sentences.\nSo',
#   'some',
#   'the',
#   'opportunity',
#   'sweat',
#   'the',
#   'these',
#   'phrase,',
#   'that',
#   'me,',
#   'someone',
#   'every',
#   'a',
#   'it.',
#   'a',
#   'space',
#   'the',
#   'that',
#   'making',
#   'that',
#   'teenagers',
#   'some',
#   'like,',
#   'my',
#   'them.',
#   'the',
#   'note',
#   'seeing',
#   'the',
#   'mine.',
#   'Al-Qaeda,',
#   'sexuality',
#   'my',
#   'us.',
#   'their',
#   'conversations',
#   'what',
#   'them',
#   'like',
#   'insignificant.',
#   'high',
#   'lying,',
#   'breaking',
#   'that.',
#   'you',
#   'you',
#   'the',
#   'disliked',
#   'a',
#   'free',
#   'spoken',
#   'them',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'put',
#   'these',
#   'novelty',
#   'bed,',
#   'ex-boyfriend,',
#   'around,',
#   'thing.',
#   'my',
#   'you',
#   'the',
#   'hope',
#   'a',
#   'communication',
#   'that',
#   'identifications.',
#   'one',
#   'her',
#   'all,',
#   'that.',
#   'all,',
#   'what',
#   'me',
#   'your',
#   'all,',
#   'these',
#   'people!',
#   'my',
#   'the',
#   'them',
#   'this?”',
#   'Newark',
#   'our',
#   'the',
#   'your',
#   'the',
#   'changing',
#   'B22.”',
#   'a',
#   'breath,',
#   'the',
#   'the',
#   'pastries',
#   'a',
#   'time.',
#   'my',
#   'Andy’s',
#   'describing',
#   'dropping',
#   'me',
#   'all',
#   'these',
#   'these',
#   'a',
#   'speed,',
#   'the',
#   'beer.”',
#   'beer.',
#   'it’s',
#   'this,',
#   'this?”',
#   'the',
#   'the',
#   'income',
#   'income',
#   'the',
#   'this',
#   'marriage,',
#   'being'],
#  'marriage.': ['And'],
#  'And': ['that',
#   'the',
#   'so',
#   'I',
#   'she',
#   'I',
#   'they',
#   'I',
#   'so',
#   'during',
#   'then',
#   'earlier',
#   'Andy',
#   'he',
#   'I',
#   'in',
#   'then',
#   'then',
#   'Jenny',
#   'I',
#   'then',
#   'I',
#   'then',
#   'I',
#   'she',
#   'then',
#   'I',
#   'often.',
#   'the',
#   'it’s',
#   'the',
#   'I’m',
#   'so',
#   'every',
#   'I’m',
#   'I',
#   'so',
#   'I',
#   'she’s',
#   'she',
#   'I',
#   'then',
#   'for',
#   'so',
#   'eventually,',
#   'it',
#   'she',
#   'for',
#   'so',
#   'those',
#   'then',
#   'collectively,',
#   'it',
#   'I',
#   'that',
#   'these',
#   'there',
#   'one',
#   'I',
#   'that’s',
#   'I’m',
#   'then',
#   'they',
#   'then',
#   'they’re',
#   'then',
#   'this',
#   'they’re',
#   'then',
#   'the',
#   'I',
#   'then',
#   'I’m',
#   'then',
#   'we',
#   'so',
#   'I’d',
#   'they’d',
#   'I’d',
#   'we’re',
#   'we',
#   'then',
#   'then',
#   'then',
#   'I’m',
#   'then',
#   'I’d',
#   'I',
#   'I',
#   'I',
#   'then',
#   'she',
#   'all',
#   'I',
#   'then',
#   'I',
#   'Tom',
#   'I',
#   'I',
#   'it',
#   'she',
#   'I',
#   'so',
#   'I',
#   'that',
#   'I',
#   'she',
#   'I',
#   'she',
#   'she',
#   'it',
#   'then',
#   'I',
#   'she',
#   'she',
#   'we',
#   'she',
#   'I',
#   'she',
#   'I',
#   'they…',
#   'I',
#   'she',
#   'I',
#   'she',
#   'every',
#   'you',
#   'I',
#   'I’ll',
#   'she’ll',
#   'I’ll',
#   'she’ll',
#   'I',
#   'she',
#   'I',
#   'she',
#   'Jenny',
#   'so',
#   'at',
#   'I',
#   'she',
#   'she',
#   'Jenny',
#   'what',
#   'I',
#   'I',
#   'I',
#   'I',
#   'he’d',
#   'he',
#   'then',
#   'she',
#   'so',
#   'I',
#   'I',
#   'a',
#   'slowly',
#   'it’s',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'this',
#   'so',
#   'I…',
#   'then',
#   'then,',
#   'I',
#   'I',
#   'there’s',
#   'he',
#   'she',
#   'I',
#   'I',
#   'I',
#   'then',
#   'I',
#   'she',
#   'I',
#   'she',
#   'I',
#   'then',
#   'there’s',
#   'I',
#   'we',
#   'every',
#   'it',
#   'I’d',
#   'finally,',
#   'we',
#   'we',
#   'then',
#   'I',
#   'she',
#   'I',
#   'she',
#   'one',
#   'I',
#   'I',
#   'I',
#   'I',
#   'Jenny',
#   'I',
#   'Jenny',
#   'I',
#   'I',
#   'then',
#   'the',
#   'I',
#   'it',
#   'it’s',
#   'I’m',
#   'I',
#   'the',
#   'Jenny’s',
#   'Andy',
#   'then',
#   'then',
#   'I',
#   'then',
#   'I',
#   'he',
#   'he',
#   'the',
#   'Andy',
#   'Andy',
#   'Andy',
#   'I',
#   'I',
#   'he',
#   'it',
#   'I’m',
#   'I',
#   'she',
#   'officer',
#   'finally,',
#   'I',
#   'he',
#   'he',
#   'he',
#   'at',
#   'he',
#   'I',
#   'I',
#   'he',
#   'in',
#   'they’d',
#   'I’m',
#   'Jenny',
#   'I',
#   'she',
#   'I'],
#  'would': ['have',
#   'anyone',
#   'be',
#   'feel',
#   'expect',
#   'be',
#   'be',
#   'invite',
#   'ask,',
#   'hate',
#   'be',
#   'they',
#   'go',
#   'let',
#   'do',
#   'recruit',
#   'be',
#   'make',
#   'talk',
#   'win.”',
#   'ever',
#   'say',
#   'pull',
#   'lick',
#   'dart',
#   'lie',
#   'go',
#   'hold',
#   'say,',
#   'be',
#   'deem',
#   'just',
#   'get',
#   'marry',
#   'have',
#   'come',
#   'never',
#   'I',
#   'be',
#   'consider',
#   'call',
#   'talk'],
#  'have': ['been',
#   'a',
#   'a',
#   'that',
#   'sex',
#   'a',
#   'to',
#   'those…',
#   'the',
#   'suggested',
#   'sort',
#   'the',
#   'a',
#   'you',
#   'a',
#   'to',
#   'a',
#   'my',
#   'laceless',
#   'a',
#   'to',
#   'to',
#   'sex',
#   'sex',
#   'a',
#   'an',
#   'that',
#   'to',
#   'a',
#   'a',
#   'a',
#   'a',
#   'not.',
#   'with',
#   '“a',
#   'a',
#   'wheels.”',
#   'to',
#   'a',
#   'enough',
#   'arri…',
#   'arrived,',
#   'ceased',
#   'been',
#   'to',
#   'one',
#   'when',
#   'near-death',
#   'any',
#   'any',
#   '$29.95.',
#   'for'],
#  'been': ['fine,',
#   'going,',
#   'doing',
#   'doing.',
#   'my',
#   'on',
#   'expelled',
#   'drinking',
#   'staying',
#   'to',
#   'arguing',
#   'like,',
#   'like,',
#   'the'],
#  'fine,': ['except'],
#  'except': ['I', 'you'],
#  'a': ['problem',
#   'real',
#   'source',
#   'learning',
#   'sure',
#   'very',
#   'car?”\nNumber',
#   'part',
#   'comedian',
#   'long,',
#   'bad',
#   'perfect',
#   'situation',
#   '90-degree',
#   't-bone',
#   'bunch',
#   'lot',
#   'great',
#   'really',
#   'sex',
#   'girl,',
#   'sex',
#   'sex',
#   'great',
#   'fixer-upper.',
#   'bad',
#   'ref',
#   'close',
#   'problem.',
#   'second?',
#   'women’s',
#   'traditional',
#   'pose',
#   'while…',
#   'lot',
#   'completely',
#   'date',
#   'date',
#   'good',
#   'break,',
#   'ride',
#   'long,',
#   'moment',
#   'broken',
#   'rejected',
#   'sore',
#   'long',
#   'sudden.',
#   'first-round',
#   'dog',
#   'while,',
#   'sad',
#   'very',
#   'lot',
#   'huge',
#   'vagina.',
#   'sense.',
#   'sudden',
#   'minute',
#   'half,',
#   'machine',
#   'truck.',
#   'very',
#   'two-person',
#   'circle,',
#   'larger',
#   'medical',
#   'little',
#   'turnoff.”',
#   'nice',
#   'little',
#   'turnoff.”',
#   'maniac.',
#   'while,',
#   'good',
#   'nephew',
#   'day.',
#   'reassuring',
#   'Ralph',
#   'scrambler',
#   'plan',
#   'fight.”',
#   'new',
#   'very',
#   'spectacle',
#   'cattle',
#   'friendly',
#   'horrible',
#   'follow-up',
#   'rocket',
#   'girl',
#   'move.',
#   'slow',
#   'classic',
#   'slow-motion',
#   'long',
#   'fidgety',
#   'head',
#   'harvest',
#   'dog',
#   'relationship',
#   'lot',
#   'terrible',
#   'restaurant',
#   'really',
#   'plan.',
#   'few',
#   'show,',
#   'bar,',
#   'few',
#   'whole',
#   'twist!',
#   'trip',
#   'lot',
#   'big',
#   'professional',
#   'license',
#   'passport.',
#   'scenario',
#   'man',
#   'pass',
#   'blank',
#   'lesbian',
#   'fiery',
#   'honeymoon.”',
#   'principle,',
#   'bad',
#   'license',
#   'passport.”',
#   'license',
#   'passport',
#   'little',
#   'basketball',
#   'game.”',
#   'good',
#   'game!”',
#   'delinquent.',
#   'really',
#   'nerd,',
#   'liar.',
#   'sport',
#   'legendary',
#   'bookie,',
#   'bunch',
#   'much',
#   'bad',
#   'few',
#   'few',
#   'family',
#   'relative.',
#   'nice',
#   'good',
#   'side',
#   'tricky',
#   'dangerous',
#   'hard',
#   'Sunday',
#   'five-day',
#   'large',
#   'small',
#   'comedy',
#   'high-low',
#   'thing.',
#   'team',
#   'cab',
#   'hickey',
#   'hickey',
#   'way',
#   'leg',
#   'hickey',
#   'person',
#   'lot',
#   'while',
#   'glimmer',
#   'text',
#   'great',
#   'license',
#   'passport.',
#   'passport.',
#   'good',
#   'principle,',
#   'chance.',
#   'part',
#   'car',
#   'government',
#   'nice',
#   'religion',
#   'wedding',
#   'fancy',
#   'flight',
#   'show',
#   'guy',
#   'laptop',
#   'road,',
#   'traveler,',
#   'tram.”',
#   'few',
#   'family,',
#   'crack',
#   'sudden,',
#   'crack',
#   'chair',
#   'pilot.',
#   'big',
#   'baby',
#   'year.',
#   'romantic',
#   'stopover',
#   'curb.',
#   'baby',
#   'baby',
#   'conclusion,',
#   'right',
#   'hit',
#   'very',
#   'command',
#   'precaution,',
#   'look',
#   'few',
#   'call',
#   'misunderstanding.',
#   'little',
#   'sudden',
#   'high',
#   'person,',
#   'sip',
#   'day,',
#   'month',
#   'man',
#   'subscription',
#   'site',
#   'great',
#   'living.',
#   'trailer',
#   'revenge',
#   'lawyer.”',
#   'restaurant,',
#   'diagram'],
#  'problem': ['where', 'is'],
#  'where': ['sometimes',
#   'you',
#   'we',
#   'I',
#   'someone',
#   'no',
#   'these',
#   'it’s',
#   'they',
#   'a',
#   'a',
#   'the',
#   'Jenny',
#   'you',
#   'I',
#   'I',
#   'I’m',
#   'is',
#   'it',
#   'I',
#   'he',
#   'he',
#   'I’m'],
#  'sometimes': ['when', 'they’ll', 'you', 'I’ll', 'have'],
#  'when': ['I',
#   'we',
#   'you',
#   'we',
#   'the',
#   'she',
#   'people',
#   'I',
#   'you’re',
#   'they',
#   'it’s',
#   'they',
#   'you',
#   'he',
#   'you’re',
#   'he',
#   'Scott',
#   'we',
#   'you’re',
#   'we',
#   'I',
#   'you',
#   'they',
#   'I'],
#  'think': ['that',
#   'it’s',
#   'people',
#   'women',
#   'that’s',
#   'I’m',
#   'it’ll',
#   'it',
#   'that?”',
#   'they’ll',
#   'it',
#   'of',
#   'you',
#   'we',
#   'we',
#   'that',
#   'I’m',
#   'it’s',
#   'the',
#   'he',
#   'we’ve',
#   'is,',
#   'of',
#   'I’ll',
#   'I’d',
#   'I’d',
#   'I’ll',
#   'I',
#   'you’re',
#   'I’m',
#   'that’s',
#   'we',
#   'that’s',
#   'they',
#   'that',
#   'it’s',
#   'that',
#   'that’s',
#   'it’s',
#   'that',
#   'we',
#   'so.’',
#   'the',
#   'that’s',
#   'I’m',
#   'it’s',
#   'that'],
#  'am': ['right', 'not', 'scrambling,', 'never', 'on'],
#  'right': ['about',
#   'now.”',
#   'about',
#   'now',
#   'away',
#   'turn',
#   'thing,',
#   'now.',
#   'thing,'],
#  'something,': ['it'],
#  'it': ['can',
#   'for',
#   'just',
#   'would',
#   'was',
#   'won’t',
#   'will',
#   'was',
#   'to',
#   'won’t',
#   'won’t',
#   'was',
#   'had',
#   'was',
#   'felt',
#   'was',
#   'like',
#   'was',
#   'still',
#   'kind',
#   'was',
#   'was',
#   'will',
#   'up',
#   'the',
#   'was',
#   'was',
#   'was',
#   'gets',
#   'has',
#   'scrambles',
#   'louder.',
#   'was',
#   'gets',
#   'was',
#   'was,',
#   'like?”',
#   '’cause',
#   'up',
#   'up',
#   'alive.',
#   'washed',
#   'go,',
#   'did',
#   'was',
#   'probably',
#   'was',
#   'off.',
#   'in',
#   'back.',
#   'doesn’t',
#   'gets',
#   'was',
#   'turns',
#   'is',
#   'would',
#   'was',
#   'a',
#   'comes',
#   'at',
#   'doesn’t',
#   'was',
#   'wasn’t',
#   'was',
#   'was',
#   'was',
#   'back.',
#   'to',
#   'was',
#   'for',
#   'were',
#   'was',
#   'was',
#   'was…',
#   'felt',
#   'would',
#   'down',
#   'would',
#   'off',
#   'just',
#   'need',
#   'was',
#   'to',
#   'was',
#   'out,',
#   'has',
#   'says',
#   'says',
#   'says',
#   'were',
#   'doesn’t…',
#   'doesn’t',
#   'sees',
#   'mean?”',
#   'works,',
#   'had',
#   'becomes',
#   'once,'],
#  'can': ['be',
#   'hear',
#   'just',
#   'I',
#   'communicate',
#   'think',
#   'see',
#   'get',
#   'all',
#   'also',
#   'do',
#   'you',
#   'feel',
#   'leave.”',
#   'clear'],
#  'be': ['a',
#   'happy.',
#   'a',
#   'the',
#   'with',
#   'like,',
#   'like,',
#   'like,',
#   'fine.”',
#   'fine.”',
#   'okay.”',
#   'offended',
#   'with',
#   'a',
#   'the',
#   'fine.”',
#   'fine',
#   'okay.”',
#   'okay.”',
#   'sad',
#   'the',
#   'like',
#   'set',
#   'a',
#   'stopped,',
#   'in',
#   'available.”',
#   'it.',
#   'where',
#   'smoking',
#   'like,',
#   'a',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'alone',
#   'like,',
#   'like,',
#   '“Jen,',
#   'difficult',
#   'into',
#   'up',
#   'a',
#   'cool.',
#   'like,',
#   'like,',
#   'impressive',
#   'at',
#   'understanding',
#   'crowned',
#   'hard',
#   'a',
#   'a',
#   'with',
#   'written',
#   'involved',
#   'a',
#   'very',
#   'doing',
#   'happening.”',
#   'dead',
#   'like,',
#   'like,',
#   'like,'],
#  'real': ['source', 'shirt', 'time'],
#  'source': ['of', 'of'],
#  'tension': ['between', 'is'],
#  'between': ['me', 'the', 'men', 'Scott'],
#  'person': ['I’m', 'to', 'has', 'you', 'you', 'in', '“you', 'who'],
#  'I’m': ['arguing',
#   'right.',
#   'implying',
#   'never',
#   'sure',
#   'at',
#   'telling',
#   'right.”',
#   'right.',
#   'driving',
#   't-boned!',
#   'spun',
#   'dead.',
#   'paralyzed.',
#   'seeing',
#   'not',
#   'not',
#   'complaining',
#   'like,',
#   'all',
#   'about',
#   'like,',
#   'gonna',
#   'going',
#   'not',
#   'not',
#   'like,',
#   'gonna',
#   'like,',
#   'like,',
#   'gonna',
#   'feeling',
#   'thinking…',
#   'thinking',
#   'scrambling,',
#   'thinking,',
#   'not',
#   'like,',
#   'back!',
#   'pretty',
#   'at',
#   'at',
#   'flanked',
#   'comfortable',
#   'just',
#   'not',
#   'saved',
#   'just',
#   'sort',
#   'trying',
#   'not',
#   'probably',
#   'never',
#   'in',
#   'out',
#   'right',
#   'supposed',
#   'always',
#   'not',
#   'into.',
#   'supposed',
#   'so',
#   '17',
#   'done,',
#   'in',
#   'gonna',
#   'assuming',
#   'noticing',
#   'hanging',
#   'good',
#   'hung',
#   'groggy.',
#   'still',
#   'sure',
#   'so',
#   'not',
#   'overtired,',
#   'angry,',
#   'late.',
#   'stuffing',
#   'flying',
#   'going.”',
#   'not',
#   'experiencing',
#   'gonna',
#   'gonna',
#   'gonna',
#   'not',
#   'gonna',
#   'a',
#   'sweaty,',
#   'out',
#   'on',
#   'so',
#   'a',
#   'so',
#   'not',
#   'blaming',
#   'right!”',
#   'right!',
#   't-boned.',
#   'spun',
#   'dead.',
#   'paralyzed.',
#   'sitting',
#   'crying',
#   'looking',
#   'okay.”',
#   'not',
#   'gonna',
#   'pretty',
#   'not',
#   'like,',
#   'calling',
#   'trying',
#   'so',
#   'on',
#   'gonna',
#   'not',
#   'writing',
#   'gonna',
#   'so',
#   'writing',
#   'ripping',
#   'just'],
#  'arguing': ['with.', 'this', 'about', 'all'],
#  'with.': ['And'],
#  'reason': ['it’s'],
#  'it’s': ['a',
#   'insane,',
#   'different.”',
#   'a',
#   'ugly',
#   'St.',
#   'all',
#   'saved',
#   'ever',
#   'just',
#   'just',
#   'not.',
#   'the',
#   'only',
#   'just',
#   'such',
#   'an',
#   'winter',
#   'the',
#   'good.',
#   'going',
#   'going',
#   'not',
#   'gonna',
#   'gonna',
#   'like,',
#   'like,',
#   'unattractive,',
#   'probably',
#   'a',
#   'a',
#   'mine.',
#   'just',
#   'only'],
#  'right.': ['And', 'And', 'He', 'I', 'That', 'Later.”', '“I’m', 'I', 'Thank'],
#  'so': ['I',
#   'we',
#   'nervous,',
#   'heartbroken,',
#   'now',
#   'I',
#   'I',
#   'much',
#   'I',
#   'I',
#   'I',
#   'stupid.',
#   'gross',
#   'I',
#   'hard,',
#   'well',
#   'when',
#   'it’s',
#   'I’m',
#   'dumb',
#   'I',
#   'devastating',
#   'a',
#   'crazy,',
#   'funny.',
#   'happy,',
#   'we',
#   'obsessed',
#   'obsessed',
#   'wrong',
#   'smart,',
#   'dumb,',
#   'excited',
#   'I',
#   'ashamed,',
#   'dumb.',
#   'we',
#   'much,',
#   'well.',
#   'I',
#   'in',
#   'I',
#   'relieved',
#   'angry.',
#   'in',
#   'good',
#   'badly',
#   'we',
#   'he',
#   'relieved.',
#   'angry,',
#   'glad',
#   'much!'],
#  'remember': ['distinctly',
#   'growing',
#   'it',
#   'so',
#   'just',
#   'getting',
#   'thinking,',
#   'the',
#   'thinking,',
#   'thinking,'],
#  'distinctly': ['talking'],
#  'talking': ['to', 'to', 'to'],
#  'my': ['friend',
#   'female',
#   'friend',
#   'friend',
#   'girlfriend',
#   'rental',
#   'hotel,',
#   'demographic.',
#   'napkin.',
#   'set',
#   'life',
#   'college',
#   'life',
#   '“A”',
#   'life',
#   'apartment.',
#   'gut',
#   'receding',
#   'gut',
#   'hairline',
#   'advantage.',
#   'I.D.',
#   'experience',
#   'breakup.',
#   'time',
#   'class',
#   'league.',
#   'homemade',
#   'mouth',
#   'friends',
#   'first',
#   'friend',
#   'appearance.',
#   'friends,',
#   'first',
#   'friends,',
#   'locker',
#   'friend',
#   'friends',
#   'thing.”',
#   'phone,',
#   'credit',
#   'cards.',
#   'ex-boyfriend,',
#   'relationship',
#   'credit',
#   'pocket',
#   'ticket',
#   'passport,',
#   'credit',
#   'work',
#   'friends.',
#   'life.”',
#   'class',
#   'uncle’s',
#   'girlfriend.',
#   'mom’s',
#   'girlfriend’s',
#   'hand,',
#   'relationship',
#   'job.',
#   'hotel',
#   'flight.',
#   'stepdad,',
#   'neck.',
#   'apartment.',
#   'apartment',
#   'business’',
#   'personal',
#   'friends',
#   'things',
#   'roller',
#   'ticket,',
#   'own',
#   'roller',
#   'flight,',
#   'family',
#   'body',
#   'flight.',
#   'show.',
#   'shows',
#   'friend',
#   'entire',
#   'friend,',
#   'totaled',
#   'mind,',
#   'life.',
#   'face,',
#   'phone,',
#   'rental',
#   'fault.”',
#   'own',
#   'own',
#   'calls,',
#   'mind,',
#   'napkin.',
#   'own',
#   'case.”'],
#  'friend': ['Dana,',
#   'Andy,',
#   'Alex',
#   'who',
#   'Andy',
#   'Sam',
#   'Tom',
#   'goes',
#   'Tom,',
#   'or',
#   'Andy’s'],
#  'Dana,': ['and'],
#  'she': ['goes,',
#   'said,',
#   'goes,',
#   'goes,',
#   'was',
#   'said,',
#   'said,',
#   'really',
#   'looks',
#   'goes,',
#   'came',
#   'thought',
#   'was',
#   'realized',
#   'was',
#   'was',
#   'warmed',
#   'was',
#   'and',
#   'told',
#   'had',
#   'says,',
#   'says,',
#   'was',
#   'had',
#   'had',
#   'had',
#   'was',
#   'goes,',
#   'said',
#   'was',
#   'had',
#   'had',
#   'stopped',
#   'hasn’t',
#   'said',
#   'says,',
#   'gave',
#   'would',
#   'says',
#   'goes,',
#   'said',
#   'said,',
#   'said,',
#   'says,',
#   'says,',
#   'said,',
#   'says,',
#   'doesn’t',
#   'goes,',
#   'puts',
#   'says,',
#   'walks',
#   'goes,',
#   'said,',
#   'says,',
#   'said,',
#   'said,',
#   'said,',
#   'likes',
#   'literally',
#   'said,',
#   'says,',
#   'was,',
#   'was,',
#   'had',
#   'was',
#   'would',
#   'would',
#   'was',
#   'told',
#   'was',
#   'was',
#   'said',
#   'had',
#   'invited',
#   'saw',
#   'would',
#   'would',
#   'said',
#   'weren’t',
#   'invites',
#   'says,',
#   'says,',
#   'said,',
#   'kneed',
#   'was',
#   'stops.',
#   'says,',
#   'said,',
#   'invites',
#   'gets',
#   'looks',
#   'goes,',
#   'said',
#   'said,',
#   'says,',
#   'says,'],
#  'goes,': ['“Well,',
#   '“You’re',
#   '“Yeah,',
#   '“What',
#   '“I',
#   '“No,',
#   '“Mike,',
#   '“well,',
#   '“well,',
#   '“you',
#   '“everyone',
#   '“you',
#   '“well,',
#   '“yeah.',
#   '“you',
#   '“I',
#   '‘yeah,',
#   '“well,',
#   '“it’s',
#   '“you’re',
#   '“yeah,',
#   '“sign',
#   '“it',
#   '“just',
#   '“well,'],
#  '“Well,': ['you', 'first', 'we', 'you', 'maybe', 'what'],
#  'you': ['don’t',
#   'believe',
#   'know,',
#   'know.',
#   'do.”',
#   'ever',
#   'know.',
#   'know.',
#   'sure',
#   'want',
#   'are',
#   'how',
#   'doing?”',
#   'think',
#   'look',
#   'kind',
#   'comedians',
#   'know.”',
#   'know,',
#   'an',
#   'follow',
#   'people?',
#   'think',
#   'are?',
#   'know.',
#   'might',
#   'know,',
#   'know,',
#   'know.',
#   'just',
#   'know.”',
#   'hear',
#   'know,',
#   'got',
#   'just',
#   'shouldn’t',
#   'have',
#   'might.',
#   'are',
#   'feel',
#   'know.',
#   'had',
#   'know,',
#   'know.',
#   'can’t',
#   'could',
#   'just',
#   'doing?”',
#   'know.',
#   'know,',
#   'know.',
#   'like',
#   'calling',
#   'seem',
#   'can',
#   'have',
#   'know.”',
#   'if',
#   'still',
#   'see',
#   'mean?”',
#   'travel?”',
#   'know,',
#   'know.',
#   'know?',
#   'think',
#   'have',
#   'have',
#   'know,',
#   'ever',
#   'could',
#   'know.',
#   'don’t',
#   'know,',
#   'know,',
#   'think',
#   'think',
#   'even',
#   'love.”',
#   'fall',
#   'know.”',
#   'want',
#   'fall',
#   'tend',
#   'at',
#   'love.\nSecond',
#   'know.”',
#   'know.”',
#   'lie',
#   'and',
#   'is',
#   'still',
#   'know',
#   'know.',
#   'suck',
#   'just',
#   'know,',
#   'know.',
#   'seem',
#   'the',
#   'have',
#   'don’t',
#   'want',
#   'can’t.',
#   'work',
#   'know.',
#   'know,',
#   'know,',
#   'believe',
#   'don’t',
#   'not',
#   'know,',
#   'sure',
#   'stay',
#   'ever',
#   'listening',
#   'up',
#   'better',
#   'what,',
#   'in',
#   'know',
#   'drop',
#   'know.',
#   'know.',
#   'owe',
#   'the',
#   'could',
#   'listening',
#   'see',
#   'have',
#   'have',
#   'what’s',
#   'doing?”',
#   'work',
#   'understand?”',
#   'guys',
#   'guys'],
#  'marriage': ['for', 'or', 'even', 'is'],
#  'but,': ['of'],
#  'course,': ['you'],
#  'other': ['people.”',
#   'people',
#   'car',
#   'person’s',
#   'people',
#   'guys,',
#   'people.',
#   'people.',
#   'people.',
#   'things',
#   'people',
#   'girl,',
#   'guy',
#   'boyfriend.',
#   'room',
#   'sort',
#   'enough,',
#   'car',
#   'car',
#   'car',
#   'driver',
#   'guy',
#   'a',
#   'driver’s',
#   'guy',
#   'driver’s',
#   'driver'],
#  'people.”': ['And'],
#  'like,': ['“No,',
#   '“Well,',
#   'for',
#   '“She',
#   'you’d',
#   '“She',
#   '“She',
#   '“That’s',
#   'scrawling',
#   '“No,',
#   '“I',
#   '“You',
#   'in',
#   '“Come',
#   '“Next',
#   '“I’m',
#   '“that',
#   '“Oh,',
#   '“No,',
#   '“No,',
#   '“No,',
#   'you',
#   '“I',
#   '“I',
#   '“I',
#   'when',
#   '“People',
#   '“I',
#   '“That',
#   '“Perfect.”',
#   '“I',
#   '“I’m',
#   'the',
#   '“we',
#   '“I',
#   '“Oh,',
#   '“Wow.”',
#   '“I’m',
#   '“We',
#   '“well',
#   '“That’s',
#   '“We',
#   '“he',
#   '“this',
#   '“hey,',
#   '“don’t',
#   '“I',
#   'this',
#   '“oh,',
#   '“yeah,',
#   'all',
#   '“oh,',
#   '“yeah,',
#   '“no,',
#   '“ah,',
#   '“moo!”',
#   '“moo!”',
#   '“oof.”',
#   '“you',
#   '“what',
#   '“I',
#   'a',
#   'some',
#   '“oh,',
#   '“how’d',
#   '“same',
#   '“hey,',
#   '“why',
#   '“oh,',
#   '“hey,',
#   '“what?”',
#   '“nothing.”',
#   '“what?”',
#   '“nothing.”',
#   '“what?”',
#   '“oh.”',
#   '“yeah,',
#   '“all',
#   '“but',
#   'a',
#   '“I',
#   '“well,',
#   '“yeah,',
#   '“yeah,',
#   'a',
#   '“this',
#   'adorable',
#   'a',
#   '“it',
#   '“awesome.”',
#   '“do',
#   '“good',
#   '“no',
#   '“you’re',
#   '“yeah,',
#   'a',
#   '“I’d',
#   '“whatever',
#   'he',
#   'wading',
#   'that',
#   '“well,',
#   '“well,',
#   '“‘I',
#   '“what',
#   '“I',
#   '“B22.',
#   '“this',
#   '“well,',
#   '“I',
#   '“I',
#   '“perfect.',
#   '“that’s',
#   '“oh,',
#   'all',
#   '“do',
#   '“all',
#   '“Drew',
#   '“oh,',
#   '“I',
#   '“case',
#   '“well,',
#   '“I',
#   '“I’m',
#   '“hey,',
#   '“I’ll',
#   '“you',
#   '“this'],
#  '“No,': ['I', 'it', 'it’ll', 'it', 'it’ll', 'it'],
#  'insane,': ['you'],
#  'know,': ['for',
#   '50%',
#   'from',
#   'and…',
#   'and',
#   'that’s',
#   'and,',
#   '“What',
#   'and',
#   'and…',
#   'it',
#   'admirers.',
#   'it’s',
#   'or',
#   'Stairway,',
#   'there’s',
#   'sometimes',
#   'the',
#   'their',
#   'uh…',
#   '11',
#   'I',
#   'I',
#   'you’re',
#   'I',
#   'that’s',
#   'it’s',
#   'I’ve',
#   'as',
#   '“I',
#   'it',
#   '“marriage',
#   'and',
#   'I’m',
#   'I’m',
#   'and,'],
#  'anyone.”': ['And'],
#  'said,': ['“Why?”\nAnd',
#   '“Well,',
#   '“Sure,',
#   '“Are',
#   '“I’m',
#   '“Why',
#   '“Well,',
#   '“It',
#   '“We',
#   '“please',
#   '“why',
#   '“you',
#   '“that',
#   '“I’m',
#   '“it',
#   '“that’s',
#   '“are',
#   '“sometimes.”',
#   '“well,',
#   '“what',
#   '“oh,',
# ...
#  'receding': ['hairline.'],
#  'hairline.': ['And'],
#  'close': ['game', 'to'],
#  'game': ['’cause'],
#  'large': ['and', 'thing'],
#  'hairline': ['is'],
#  'fast,': ['and'],
#  'riled': ['up.'],
#  'up.': ['I’m', '“You', 'I'],
#  'charge': ['the', 'of', 'of', 'of'],
#  'field.': ['And'],
#  'guy': ['comes',
#   'says,',
#   'goes,',
#   'can’t',
#   'goes,',
#   'says,',
#   'lets',
#   'in',
#   'comes',
#   'with',
#   'drunk?”',
#   'was',
#   'was'],
#  'comes': ['by', 'in', 'over,', 'up', 'over', 'out', 'over,'],
#  'fried': ['dough.', 'dough,'],
#  'dough.': ['And'],
#  '“Next': ['time.”'],
#  'time.”': ['You'],
#  'dough,': ['’cause'],
#  'problem.': ['I'],
#  'just…': ['This', 'Popcorn,', 'I', 'I'],
#  'ridiculous.': ['Can'],
#  'Can': ['you'],
#  'follow': ['me'],
#  'over': ['here',
#   'these',
#   'the',
#   'very',
#   'lunch,',
#   'to',
#   'so',
#   'to',
#   'the',
#   'my'],
#  'here': ['for', 'in', 'at', 'tonight'],
#  'second?': ['I’m'],
#  'jump': ['off', 'up,'],
#  'stage.': ['This'],
#  'Seattle': ['where'],
#  'wearing': ['no'],
#  'no': ['shoes?',
#   'matter',
#   'one',
#   'video',
#   'license',
#   'passport,',
#   'one',
#   'one',
#   'way',
#   'to,',
#   'regard'],
#  'shoes?': ['No'],
#  'No': ['shoes', 'one'],
#  'shoes': ['or'],
#  'socks?': ['What?'],
#  'What?': ['Who'],
#  'Who': ['are'],
#  'people?': ['What'],
#  'What': ['is', 'is', 'is', 'is', 'was'],
#  'wrong': ['with', 'frozen', 'about'],
#  'you?': ['I', 'I'],
#  'expect': ['that'],
#  'behavior': ['from'],
#  'guy,': ['but'],
#  'sir,': ['not'],
#  'you!': ['What'],
#  'this?': ['Where'],
#  'Where': ['do'],
#  'are?': ['From'],
#  'From': ['Seattle!'],
#  'Seattle!': ['Yeah,'],
#  'going,': ['uh,', 'so', '“we', '“but'],
#  'uh,': ['recently', 'we’re', 'I', 'I', 'I’m'],
#  'recently': ['to'],
#  'women’s': ['exercise'],
#  'exercise': ['class.'],
#  'class.': ['I-I’ve'],
#  'I-I’ve': ['given'],
#  'given': ['up', 'up'],
#  'having': ['a', 'a', 'on', 'a'],
#  'traditional': ['male'],
#  'male': ['physique.'],
#  'physique.': ['And'],
#  'now': ['I’m', 'that’s', 'I', 'because', '’cause', 'on,', 'I'],
#  'going': ['for',
#   'pretty',
#   'out',
#   'to',
#   'down',
#   'on',
#   'well.',
#   'pretty',
#   'away',
#   'completely',
#   'on?”',
#   'on!”',
#   'to'],
#  'strong,': ['independent', 'and'],
#  'independent': ['woman.'],
#  'woman.': ['And,'],
#  'And,': ['uh…', 'uh…', 'yeah,', 'uh…', 'uh…', 'uh,'],
#  'well,': ['you', '“and', 'she’ll'],
#  'class': ['as', 'were', 'into', 'named', 'named'],
#  'think.': ['Sometimes'],
#  'Sometimes': ['I’ll', 'she’ll'],
#  'skip': ['whole'],
#  'sections': ['of'],
#  'exercises': ['when'],
#  'instructor': ['isn’t'],
#  'looking.': ['But'],
#  'looks': ['over,', 'at', 'at'],
#  'over,': ['I', 'and', 'and', 'and'],
#  'always': ['have', 'feared', 'two', 'try'],
#  'strike': ['a'],
#  'pose': ['as'],
#  'though': ['I’ve', 'she', 'I', 'I'],
#  'doing': ['what',
#   'that.”',
#   'laps,',
#   'here?”',
#   'there?”',
#   'that',
#   'something'],
#  'everybody': ['else'],
#  'else': ['has'],
#  'doing.': ['It'],
#  'It': ['reminds',
#   'seemed',
#   'seemed',
#   'was',
#   'travels',
#   'is',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was…',
#   'was',
#   'was',
#   'is',
#   'was',
#   'was',
#   'was'],
#  'reminds': ['me'],
#  'Olympics.': ['You'],
#  'gymnastics,': ['how'],
#  'those…': ['The'],
#  'The': ['girls',
#   'other',
#   'rest',
#   'premise',
#   'new',
#   'mathematics',
#   'third',
#   'point',
#   'way',
#   'next',
#   'Matrix',
#   'news',
#   'roller',
#   'happy',
#   'sad',
#   'officer',
#   'officer',
#   'other',
#   'doctor',
#   'next',
#   'other',
#   'officer',
#   'problem'],
#  'girls': ['will', 'in', 'from', 'from'],
#  'those': ['crazy', 'are…', 'romantic', 'conversations'],
#  'flips': ['and'],
#  'twirls.': ['And'],
#  'every': ['once',
#   'night',
#   'once',
#   'week.”',
#   'five…',
#   'night',
#   'once',
#   'flight',
#   'night'],
#  'once': ['in', 'in', 'in'],
#  'while…': ['And'],
#  'root': ['for'],
#  'happen,': ['but'],
#  'fall,': ['and'],
#  'ugly': ['’cause'],
#  'they’re': ['rolling',
#   'like',
#   'like,',
#   'like,',
#   'just',
#   'lesbians,',
#   'competitive',
#   'sort',
#   'the',
#   'handing'],
#  'rolling': ['around'],
#  'around': ['like,', 'me,', 'me.', 'like,', '3:30'],
#  'trouble.': ['Like,'],
#  'here.”': ['But', 'And'],
#  'matter': ['what…'],
#  'what…': ['And', 'what'],
#  'totally': ['fall', 'messed', 'see'],
#  'fall': ['for', 'away', 'in', 'in', 'asleep.'],
#  '“that': ['can’t', 'makes', 'seems', 'I', 'sounds', 'matches'],
#  'can’t': ['possibly',
#   'be',
#   'really',
#   'imagine',
#   'choose',
#   'help',
#   'answer',
#   'be'],
#  'possibly': ['be'],
#  'same': ['loser', 'way', 'bus'],
#  'loser': ['“From'],
#  '“From': ['moments'],
#  'moments': ['ago.'],
#  'ago.': ['“I'],
#  'completely': ['different', 'qualified.”\nI', 'bewildering.', 'mad.\nI’m'],
#  'different': ['person.', 'mouth'],
#  'person.': ['“This', 'I'],
#  '“This': ['person', 'could'],
#  'posture,': ['for'],
#  'starters.”': ['I'],
#  'night': ['in', 'went', 'went', 'to', 'about', 'I', 'we’d', 'just'],
#  'Louis': ['’cause'],
#  'these': ['famous',
#   'two',
#   'homophobic',
#   'guys',
#   'were',
#   'other',
#   'items.',
#   'girls',
#   'phrases',
#   'great',
#   'Afghani',
#   'were',
#   'sort',
#   'like,',
#   'people?”',
#   'epiphanies',
#   'things',
#   'days'],
#  'famous': ['Irish'],
#  'Irish': ['pubs', 'pub,', 'pub,'],
#  'pubs': ['where'],
#  'speak.': ['And'],
#  'thought': ['that', 'she', 'was', 'was', 'it', 'he'],
#  'work': ['to', 'I.D.”', 'at', 'in', 'out.”', 'out', 'on'],
#  'advantage.': ['I'],
#  'and,': ['uh…', 'uh…', 'you', 'uh…', 'uh,', 'I'],
#  'nerve': ['to'],
#  'ask': ['her', 'her', 'her', 'her'],
#  'myself,': ['and', '“well,'],
#  'convinced': ['Andy'],
#  'Pfft.': ['Which…'],
#  'Which…': ['yeah,'],
#  'yeah,': ['I', 'that', 'I', 'nice.'],
#  '’cause,': ['uh,'],
#  'heading…': ['We’re'],
#  'heading': ['to', 'back', 'to'],
#  'pub,': ['and', 'and', 'and', 'nice.”', 'nice.”'],
#  'says,': ['“Oh,',
#   '“Sure.”',
#   '“Oh,',
#   '“Well,',
#   '“you',
#   '“oh,',
#   '“how',
#   '“yeah,',
#   '“yes.”',
#   '“congratulations',
#   '“that’s',
#   '“no,',
#   '“yeah,',
#   '‘I’ll',
#   '‘I’ll',
#   '“that’s',
#   '“you',
#   '“well,',
#   '“you',
#   '“where',
#   '“I',
#   '“I',
#   '“why?”',
#   '“well,',
#   '“that’s',
#   '“what',
#   '“well,',
#   '“was',
#   '“well,',
#   '“Mike…',
#   '“Mike…',
#   '“do',
#   '“do',
#   '“did',
#   '“what',
#   '“well,',
#   '“Mike…'],
#  '“Oh,': ['I', 'we', 'no,', 'this'],
#  'left': ['my', 'in'],
#  'I.D.': ['at'],
#  'hotel.”': ['And'],
#  'swing': ['back'],
#  'it.”': ['And', 'I’m', 'But', 'She', 'And', 'He'],
#  'like…': ['she’s', 'No,', 'It', '10', '“Maybe'],
#  'fine': ['’cause', 'for'],
#  'Patrick’s': ['day,'],
#  'day,': ['and', 'but', 'Jenny', 'leaving'],
#  'there’s': ['bouncers.”',
#   'something',
#   'no',
#   'an',
#   'Amanda,',
#   'her',
#   '15',
#   'Jenny,',
#   'her',
#   'her',
#   'no',
#   'a'],
#  'bouncers.”': ['And'],
#  'fine.': ['Like,', '“You'],
#  'bouncer': ['just'],
#  'waved': ['her'],
#  'through,': ['which'],
#  'experience': ['with'],
#  'bouncers.': ['For'],
#  'For': ['me,'],
#  'bouncers': ['are'],
#  'prison': ['guards.'],
#  'guards.': ['And'],
#  'birthday': ['clowns'],
#  'clowns': ['like,'],
#  'day': ['better?”\nYou', 'I', 'on', 'took', 'on'],
#  'better?”\nYou': ['know,'],
#  'that’s…': ['We’re', 'That’s', 'that’s'],
#  'taken': ['so'],
#  'convincing': ['for'],
#  'there.': ['By', 'You’re', 'Is', 'There’s'],
#  'By': ['the'],
#  'time': ['she', 'in', 'I', 'we', 'I', 'I', 'I', 'where', '’cause', 'and…\nI'],
#  'came': ['out,', 'from'],
#  'out,': ['she', 'but', 'when', 'and'],
#  'date': ['with', 'with', 'is', 'two'],
#  'him.': ['And,', 'He', 'There', 'Now,', 'And'],
#  'wasn’t': ['the', 'even', 'even', 'even', 'front', 'even'],
#  'idea.': ['And', '“But', '“You'],
#  'said…': ['I', 'They'],
#  'convince': ['him', 'myself,'],
#  'on,': ['like', 'but', 'I', 'she', '“and'],
#  'red': ['rockets', 'flags.', 'flag', 'flag', 'flag'],
#  'rockets': ['on'],
#  'space': ['shuttle.', 'in'],
#  'shuttle.': ['And'],
#  'eventually,': ['she'],
#  'realized': ['she'],
#  'happy': ['about', 'side'],
#  'But,': ['uh…'],
#  'warmed': ['to'],
#  'drinking,': ['and'],
#  'then,': ['like…', 'again,', 'if'],
#  'laughing': ['and', 'so'],
#  'time,': ['and', 'but'],
#  'we…': ['I', 'At'],
#  'caught': ['a'],
#  'break,': ['which'],
#  'shared': ['a'],
#  'ride': ['back', 'would'],
#  'our': ['hotel',
#   'new',
#   'sweaty',
#   'friend',
#   'honeymoon.”',
#   'final',
#   'hotel,',
#   'relationship',
#   'apartment.'],
#  'their': ['friends,', 'relationship', 'lives', 'first', 'house'],
#  'friends,': ['and', 'but', 'until', 'and'],
#  'stuffed': ['in'],
#  'little': ['back', 'bit', 'bit', 'bit', 'stuff,', 'bit'],
#  'seat': ['together.', 'belt', 'belt', 'belt'],
#  'together.': ['And', 'And', 'And', 'We', 'And'],
#  'quiet,': ['so'],
#  'could': ['hear',
#   'be',
#   'be',
#   'mess',
#   'see',
#   'see',
#   'bud',
#   'put',
#   'sense',
#   'put',
#   'recruit',
#   'get',
#   'see',
#   'be',
#   'totally',
#   'make',
#   'end',
#   'have',
#   'communicate',
#   'get',
#   'do'],
#  'soft': ['voice.'],
#  'voice.': ['And'],
#  'told': ['me', 'her', 'me', 'me', 'you'],
#  'breakup,': ['and'],
#  'breakup.': ['And'],
#  'seat,': ['it'],
#  'felt': ['like', 'so', 'so', 'like'],
#  'holding': ['up'],
#  'two': ['halves',
#   'very',
#   'aliens',
#   'dudes',
#   'distinct',
#   'cows',
#   'mouths.',
#   'people',
#   'hours',
#   'hours',
#   'people',
#   'hours',
#   'or'],
#  'halves': ['of', 'of'],
#  'broken': ['paper'],
#  'paper': ['heart,'],
#  'heart,': ['and…'],
#  'offer': ['to', 'are'],
#  'walk': ['her', 'in', 'in', 'out', 'out', 'you'],
#  'room,': ['and', 'and'],
#  '“Sure.”': ['We'],
#  'door,': ['and', 'and', 'and'],
#  'end.': ['And'],
#  'build': ['up'],
#  'courage': ['to', 'to', 'to'],
#  'lean': ['in', 'in'],
#  'kiss': ['her,', 'that', '’cause', 'Jenny,', 'or', 'or'],
#  'her,': ['and', 'kind', 'I', 'and'],
#  'Which': ['I', 'I', 'is', 'is', 'is'],
#  'polite…': ['But'],
#  'disappointing.': ['I'],
#  'something': ['about', 'on', 'was', '“that'],
#  'rejected': ['kiss'],
#  'personal': ['type', 'relationships.'],
#  'type': ['of'],
#  'rejection': ['because'],
#  'putting': ['yourself'],
#  'yourself': ['out'],
#  'You’re': ['just', 'like,'],
#  'should': ['connect',
#   'connect',
#   'have',
#   'call',
#   'do',
#   'go',
#   'play.”',
#   'just',
#   'live',
#   'be',
#   'get',
#   'focus'],
#  'connect': ['mouths,”', 'mouths.”', 'mouths,'],
#  'mouths,”': ['you'],
#  'person’s': ['like,'],
#  'mouths.”': ['And'],
#  'are…': ['They’re'],
#  'They’re': ['two', 'like,', 'like,', 'both'],
#  'mouth': ['agendas,', 'virginity', 'war.'],
#  'agendas,': ['you'],
#  'stupid.': ['You’re'],
#  'suggested': ['we', 'that'],
#  'mouths,': ['you'],
#  'sore': ['subject'],
#  'subject': ['for'],
#  'sort': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'long': ['history', 'song,', 'I'],
#  'history': ['of'],
#  'failed': ['kisses.', 'kiss'],
#  'kisses.': ['Like,'],
#  'growing': ['up,'],
#  'up,': ['like,', 'and', 'she', 'but', 'and'],
#  'making': ['out.',
#   'out',
#   'out',
#   'out',
#   'sure',
#   'out.',
#   'out,',
#   'out.',
#   'out',
#   'out',
#   'out',
#   'this',
#   'this'],
#  'out.': ['Like,', 'Is', '“It’ll', 'I', 'At', 'No'],
#  'Massachusetts,': ['it'],
#  'seventh': ['grade.', 'grade,'],
#  'grade.': ['I'],
#  'remember…': ['I'],
#  'yesterday': ['’cause'],
#  'shocked.': ['I'],
#  '“People': ['we'],
#  'know?”': ['“But'],
#  '“But': ['how?”', 'who'],
#  'how?”': ['You'],
#  'seemed': ['like', 'so', 'like', 'in'],
#  'alien': ['ritual'],
#  'ritual': ['where'],
#  'aliens': ['just'],
#  'attach': ['orifices'],
#  'orifices': ['all'],
#  'sudden.': ['I'],
#  'that.”': ['And', 'And', 'She'],
#  'collectively,': ['all'],
#  '“That': ['is', 'is', 'is'],
#  'list.': ['“You’re'],
#  'exactly': ['a', 'how'],
#  'first-round': ['draft'],
#  'draft': ['pick'],
#  'pick': ['for', 'up', 'up'],
#  'new': ['activity.”', 'plan.”', 'plan', 'clause!', 'year’s,'],
#  'activity.”': ['I'],
#  '“Perfect.”': ['It'],
#  'gross': ['to'],
#  'still': ['does',
#   'feel',
#   'kind',
#   'seeing',
#   'arguing',
#   'wants',
#   'two',
#   'together,',
#   'didn’t',
#   'don’t.'],
#  'does': ['kind', 'it', 'a', 'not', 'it', 'for'],
#  'of.': ['Like,'],
#  'homophobic': ['arguments'],
#  'arguments': ['from'],
#  'guys': ['who', 'by', 'who', 'very', 'so'],
#  'dudes': ['making'],
#  'street.”': ['And'],
#  'anyone.': ['Like,'],
#  'sloppy.': ['It’s'],
#  'watching': ['a'],
#  'dog': ['eat', 'eating'],
#  'eat': ['spaghetti.', 'popcorn', 'poison,'],
#  'spaghetti.': ['That’s'],
#  'Is': ['that', 'it'],
#  'right?': ['Does', 'Okay,', 'Like,', 'That’s'],
#  'Does': ['anybody'],
#  'anybody': ['know'],
#  'Okay,': ['good.'],
#  'So…': ['In', 'uh…', 'Cattle', 'Ten'],
#  'In': ['seventh', 'Bermuda,', 'Texas.', '1'],
#  'grade,': ['I'],
#  'anybody.”': ['And'],
#  'while,': ['but', 'he’s'],
#  'increasingly,': ['it'],
#  'divided': ['the'],
#  'into': ['two',
#   'the',
#   'a',
#   'that',
#   'that',
#   'my',
#   'these',
#   'an',
#   'my',
#   'the',
#   'celebrating',
#   'a',
#   'this',
#   'him.',
#   'my'],
#  'distinct': ['parts.'],
#  'parts.': ['It'],
#  'make-out': ['club', 'club.”', 'anthem.'],
#  'club': ['and', 'to', 'all'],
#  'non-make-out': ['club.', 'club', 'club,', 'club,', 'club!”'],
#  'club.': ['And', 'Well,', 'Now,'],
#  'informal': ['organizations,'],
#  'organizations,': ['of'],
#  'course.': ['I'],
#  'sad': ['if', 'group,', 'side', 'side'],
#  'school-sanctioned,': ['like,'],
#  '“we': ['call', 'should', 'need'],
#  'meeting': ['of', 'your'],
#  'order.': ['“First', 'Bazetti,'],
#  '“First': ['order'],
#  'order': ['of', 'of'],
#  'business,': ['Nintendo.', 'why'],
#  'Nintendo.': ['“Second'],
#  '“Second': ['order', 'of'],
#  'why': ['doesn’t', 'it', 'you’re', 'are', 'they', 'don’t'],
#  'doesn’t': ['anyone',
#   'enjoy',
#   'mean',
#   'have',
#   'mean',
#   'go',
#   'seem',
#   'understand',
#   'take'],
#  'us?': ['Meeting'],
#  'Meeting': ['adjourned.”'],
#  'adjourned.”': ['I'],
#  'group,': ['and'],
#  'losing': ['good', 'interest,'],
#  'day.': ['I', 'I', 'I'],
#  'feared…': ['I'],
#  'feared': ['that', 'at', 'if'],
#  'soon': ['I'],
#  'lone': ['member', 'member'],
#  'member': ['of', 'of'],
#  'club,': ['so', 'but'],
#  'try': ['to', 'to'],
#  'club.”': ['But'],
#  'intangible': ['goal.'],
#  'goal.': ['I'],
#  'talk': ['to',
#   'to',
#   'about',
#   'about',
#   'about.',
#   'about',
#   'about',
#   'about',
#   'to'],
#  'girls,': ['and…'],
#  'girl': ['who', 'says', 'says,'],
#  'sat': ['in'],
#  'front': ['of', 'of', 'door,', 'door,', 'and', 'of', 'of'],
#  'named': ['Lisa', 'Keith'],
#  'Lisa': ['Bazetti', 'Bazetti', 'on'],
#  'Bazetti': ['who', 'to'],
#  'huge': ['crush'],
#  'crush': ['on,'],
#  'league.': ['Like,'],
#  'many': ['suitors.', 'suitors!', 'minutes'],
#  'suitors.': ['She'],
#  'had…': ['I'],
#  'don’t…': ['The', 'I'],
#  'rest': ['of', 'of', 'of'],
#  'show': ['is', 'her', 'all', 'her', 'Saturday', 'I', 'you'],
#  'old': ['English.', '“and'],
#  'English.': ['Uh…'],
#  'Uh…': ['She', 'It’s'],
#  'doth': ['had'],
#  'suitors!': ['Uh,'],
#  'many,': ['you'],
#  'admirers.': ['And'],
#  'us,': ['really,'],
#  'really,': ['and'],
#  'third': ['place', 'time'],
#  'place': ['in'],
#  'trade': ['publications,'],
#  'publications,': ['but'],
#  'advantage': ['over'],
#  'guys,': ['which'],
#  'phone': ['every', 'that', '’cause', 'with', 'numbers'],
#  'homework,': ['thanks'],
#  'thanks': ['to'],
#  'alphabetical': ['order.'],
#  'Bazetti,': ['Birbiglia.'],
#  'Birbiglia.': ['One'],
#  'One': ['time', 'time', 'of', 'of', 'night,', 'night,'],
#  'said': ['something',
#   'yes.',
#   'to',
#   'that',
#   'to',
#   '“you’re',
#   'of',
#   'she',
#   'about',
#   'it',
#   'to',
#   'it',
#   'earlier,',
#   'no'],
#  'made': ['her', 'a'],
#  'laugh,': ['and'],
#  'great.': ['I', 'I'],
#  'more.”': ['And'],
#  'hard,': ['I'],
#  'well': ['’cause', 'in', 'connected', 'as'],
#  '“Mike,': ['you'],
#  'stop.': ['I’m'],
#  'pee': ['myself.”'],
#  'myself.”': ['And'],
#  '“Wow.”': ['This'],
#  'closest': ['I’d'],
#  'vagina.': ['So'],
#  'spent': ['the'],
#  'next': ['15', 'morning,', 'to', 'tram', 'tram', 'one', 'morning,', 'to'],
#  '15': ['years', 'bachelorette'],
#  'trying': ['to', 'not', 'not', 'to'],
#  'pee.': ['And'],
#  'ended': ['up', 'up', 'up', 'up', 'up'],
#  'here,': ['in', 'you'],
#  'sense.': ['So…', 'I’ve'],
#  'here’s': ['what'],
#  'happened': ['with'],
#  'Lisa.': ['One', 'But'],
#  'built': ['up', 'up'],
#  'carnival': ['with', 'workers', 'salsa.'],
#  'yes.': ['I'],
#  'couldn’t': ['believe', 'because', 'even', 'explain', 'say,', 'afford'],
#  'sudden': ['I', 'V-1…'],
#  'thought,': ['“Well,', '“well,'],
#  'maybe': ['this', 'it'],
#  '“one': ['of'],
#  'romantic': ['comedy', 'comedy', 'comedy.'],
#  'comedy': ['montages.', 'version', 'club.', 'clubs', 'part.'],
#  'montages.': ['“We’ll'],
#  '“We’ll': ['go'],
#  'carnival,': ['we’ll'],
#  'we’ll': ['get', 'make', 'dress'],
#  'stuck': ['“On'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=9):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(mike_dict)
# Out:
# 'Get to lean in charge of this oral atrocity.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.
